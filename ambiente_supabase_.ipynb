# %% [markdown]
# <a href="https://colab.research.google.com/github/pie-tro/Canil/blob/main/ambiente_supabase_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install supabase python-dotenv
from google.colab import drive


SUPABASE_URL="https://sjseehkgyrkarejybhjg.supabase.co"
SUPABASE_KEY="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InNqc2VlaGtneXJrYXJlanliaGpnIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NDYyNzI1MzYsImV4cCI6MjA2MTg0ODUzNn0.U6_t-WL1WrgfmncBp66tgXCrf8Wny9h2Yys7Cvkg4rg"
from supabase import create_client
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)


resposta = supabase.table("animais").select("*").execute()
print(resposta.data)


novo_animal = {
    "nome": "Rex",
    "especie": "Cachorro",
    "idade": 4,
    "adotado": False
}
resposta = supabase.table("animais").insert(novo_animal).execute()
print(resposta.data)


resposta = supabase.table("animais").update({"adotado": True}).eq("id", 1).execute()
print(resposta.data)


resposta = supabase.table("animais").delete().eq("id", 2).execute()
print(resposta.data)


def cadastrar_animal(nome, especie, idade):
    return supabase.table("animais").insert({
        "nome": nome,
        "especie": especie,
        "idade": idade,
        "adotado": False
    }).execute()
# Out:
# ...
# [{'id': 1, 'nome': 'Rex', 'especie': 'Cachorro', 'raca': None, 'porte': None, 'sexo': None, 'idade': 4, 'cor': None, 'dataentrada': '2025-05-03', 'status': 'Disponivel', 'adotado': 'true'}]
# [{'id': 3, 'nome': 'Rex', 'especie': 'Cachorro', 'raca': None, 'porte': None, 'sexo': None, 'idade': 4, 'cor': None, 'dataentrada': '2025-05-03', 'status': 'Disponivel', 'adotado': 'false'}]
# [{'id': 1, 'nome': 'Rex', 'especie': 'Cachorro', 'raca': None, 'porte': None, 'sexo': None, 'idade': 4, 'cor': None, 'dataentrada': '2025-05-03', 'status': 'Disponivel', 'adotado': 'true'}]
# []
